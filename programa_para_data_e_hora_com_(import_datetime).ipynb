# %% [markdown]
# <a href="https://colab.research.google.com/github/emerson-jose/python-learning/blob/main/programa_para_data_e_hora_com_(import_datetime).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## DATA E HORA


import datetime

hj = datetime.datetime.now()
print(hj)

# %%
from datetime import datetime

hj= datetime.now()
print(hj)

# %%
from datetime import datetime

import pytz

pst=pytz.timezone('America/Sao_paulo')
d= datetime.now()
print ("sem time zone",d)
d=d.astimezone(pst)
print ("com time zone",d)

# %%
print ("ano",hj.year)
print ("mes",hj.month)
print ("dia",hj.day)
print ("hora",hj.hour)
print ("minuto",hj.minute)
print ("segundo",hj.second)
print ("microsegundo",hj.microsecond)
print ("data",hj.date())
print ("hora",hj.time())

# %%
dt = hj.date()
print("dia da semana",dt.weekday())

print ("dia da semana",{0:"segunda",1:"terça", 2:"quarta",3:"quinta", 4:"sexta",5:"sabado"} [dt.weekday()])
