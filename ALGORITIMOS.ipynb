# %% [markdown]
# <a href="https://colab.research.google.com/github/emerson-jose/python-learning/blob/main/ALGORITIMOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = input("digite seu nome:")
print (f"ola,{nome}! é umprazer")

carro = input("qual o nome do seu carro")
print(f"show esse seu {carro}!")
# Out:
# digite seu nome:emerson
# ola,emerson! é umprazer
# qual o nome do seu carroBYD
# show esse seu BYD!

# %%
print("Operadores Aritméticos em Python:\n")
print("+ : Adição\n")
print("- : Subtração\n")
print("* : Multiplicação\n")
print("/ : Divisão (retorna um float)\n")
print("// : Divisão inteira (retorna a parte inteira da divisão)\n")
print("% : Módulo (retorna o resto da divisão)\n")
print("** : Exponenciação\n")
# Out:
# Operadores Aritméticos em Python:
#
# + : Adição
#
# - : Subtração
#
# * : Multiplicação
#
# / : Divisão (retorna um float)
#
# // : Divisão inteira (retorna a parte inteira da divisão)
#
# % : Módulo (retorna o resto da divisão)
#
# ** : Exponenciação

# %%
# solicitação do primeiro numero
n1_str= input("digite o primeiro numero: ")
n1 = int(n1_str)
# solicitação do segundo numero
n2_str= input("digite o segundo numero: ")
n2 = int(n2_str)
m = 2
media = int(m)
# soma das duas variaveis
soma = (n1+n2)/ m

# exeibição dos resultdos
print(f"o primeiro numero digitado de foi: {n1}!")

print(f" o segundo numero digitado foi: {n2}!")

print (f" a media de n1 + n2 foi: {soma}")
# Out:
# digite o primeiro numero: 3
# digite o segundo numero: 4
# o primeiro numero digitado de foi: 3!
#  o segundo numero digitado foi: 4!
#  a media de n1 + n2 foi: 3.5

# %%
import math
# SOLICIT QUE O USUARIO ESCREVA O ANGULO EM GRAUS
angulo = float(input("digite um angulo em graus : ") )

#CONVERTE O ANGULO DE GRUAS PARA RADIANOS
angulo_radianos = math.radians(angulo)


#CALCULA O SENO DO ANGULO
s = math.sin(angulo_radianos)

print (f"o seno de {angulo} é igual a :{s:.2f} ")
# Out:
# digite um angulo em graus : 60
# o seno de 60.0 é igual a :0.87

# %%
nome = input("digite seu nome: ")

# Solicita o sexo do usuário e converte para minúsculas, removendo espaços em branco
sexo = input("digite seu sexo:\n (M) para masculino\n(F) fpara feminino \n").strip().lower()

if sexo == "m":
 print (f" {nome} seja bem vindo")

elif sexo == "f":
  print (f" {nome} seja bem vinda")

else:
  print (f"muito prazer {nome} em ter vc aqui!")
# Out:
# digite seu nome: emerson jose
# digite seu sexo:
#  (M) para masculino
# (F) fpara feminino
# m
#  emerson jose  seja bem vindo

# %%
# COMPARAR DOIS NUMEROS SE SAO IGUAIS
x= input("digite o primeiro numero: ")
y= input('digite o segundo numero: ')


print(f"{x} {y} : {x == y }")
# Out:
# digite o primeiro numero: 3
# digite o segundo numero: 3
# 3 3 : True

# %%
idade = int(input("Digite sua idade: "))

# Verifica se a idade é maior ou igual a 18
if idade >= 18:
  print("Você é maior de idade.")
elif idade > 0 and idade < 18:
  print("Você é menor de idade.")
else:
  print("Idade inválida.")
# Out:
# Digite sua idade: 21
# Você é maior de idade.

# %%
# Exemplos de valores booleanos
verdadeiro = True
falso = False

print(f"Variável 'verdadeiro': {verdadeiro}")
print(f"Variável 'falso': {falso}")

print("\n--- Operadores de Comparação ---")
# Operadores de comparação retornam True ou False
x = 10
y = 5

print(f"{x} > {y}: {x > y}")   # Maior que
print(f"{x} < {y}: {x < y}")   # Menor que
print(f"{x} == {y}: {x == y}") # Igual a
print(f"{x} != {y}: {x != y}") # Diferente de
print(f"{x} >= {y}: {x >= y}") # Maior ou igual a
print(f"{x} <= {y}: {x <= y}") # Menor ou igual a

print("\n--- Operadores Lógicos ---")
# Operadores lógicos combinam valores booleanos
p = True
q = False

print(f"{p} and {q}: {p and q}") # AND lógico (ambos True)
print(f"{p} or {q}: {p or q}")   # OR lógico (pelo menos um True)
print(f"not {p}: {not p}")      # NOT lógico (inverte o valor)
# Out:
# Variável 'verdadeiro': True
# Variável 'falso': False
#
# --- Operadores de Comparação ---
# 10 > 5: True
# 10 < 5: False
# 10 == 5: False
# 10 != 5: True
# 10 >= 5: True
# 10 <= 5: False
#
# --- Operadores Lógicos ---
# True and False: False
# True or False: True
# not True: False

# %%
L1 = input('digite o primeiro numero:')
L2= input("digite o segundo numero: ")
L3 = input("digite o terceiro numero: ")

L1 = int (L1)
L2 = int (L2)
L3 = int (L3)

if L1 == L2 and L2 == L3:
  print ("EQUILATERO")
elif L1 != L2 and L2 != L3 and L1 != L3:
 print ("ESCALENO")
 # The condition for a triangle should be checked independently or within the relevant branches
 if L1 < L2 + L3 and L2 < L1 + L3 and L3 < L1 + L2:
  print ("TRIANGULO")
else:
  print ("ISOSCELES") # Assuming the user meant ISOSCELES here
# Out:
# digite o primeiro numero:20
# digite o segundo numero: 30
# digite o terceiro numero: 40
# ESCALENO
# TRIANGULO

# %%
reais_str = input("digite quantos reais para converter:")

# Replace comma with period for decimal conversion
reais_str = reais_str.replace(',', '.')

# Convert the input string to a number (float for potential decimal values)
reais = __builtins__.float(reais_str)

dola = 5.5

# The variable dola is already a float, no need to convert to int if you want to keep the decimal
# dola = int(dola) # Uncomment this line if you specifically need an integer exchange rate

x = reais
y = dola


soma= x * y

print (f"o valor da conversao foi de {soma}")
# Out:
# digite quantos reais para converter:250
# o valor da conversao foi de 1375.0

# %%
nome = input("digite seu nome: ")

ano_nacimento = input("digite seu ano de nascimento: ")

ano_atual = input("digite ano atual: ")


x = int (ano_nacimento )

y = int (ano_atual)

soma = y-x

print (f"ola {nome }sua idade é {soma}")
# Out:
# digite seu nome: EMERSON
# digite seu ano de nascimento: 2004
# digite ano atual: 2025
# ola EMERSONsua idade é 21

# %%
farenrit = input("informe a temperatura em firenrit:")
f = int(farenrit)

c = (f - 32) / 1.8
print (f"{c:.4f}")
# Out:
# informe a temperatura em firenrit:100
# 37.7778

# %%
nome_produto = input ("nome do produto: ")

preco_produto = input("qual o valor do produto?: ")

p = (preco_produto).replace(',', '.')
p = __builtins__.float(p)

taxa = 60

t=(taxa)


soma =  60/100 + p

valor_final = print(f" o valor final do {nome_produto} foi de  {soma} !!!")
# Out:
# nome do produto: BLOCOS
# qual o valor do produto?: 200
#  o valor final do BLOCOS foi de  200.6 !!!

# %%
nome_cliente = input("qual o seu nome? : \n")

valor_emprestimo = input("valor do empretimo: \n")

emprestimo = (valor_emprestimo).replace(',', '.')
emprestimo = __builtins__.float(valor_emprestimo)

juros = 20
x = (emprestimo)

y = (juros)

soma = y*x / 100 + x

parcelar = input("gostaria de parcelar? : \n")


parcelar = parcelar.strip().lower()
if parcelar == "sim":
 qtd_parcelas= input("informe quantas parcelas: \n")
 qtd_parcelas = int(qtd_parcelas)

 print(f"O total de suasparcelas ficaram de {soma / qtd_parcelas}\n")

elif parcelar == "nao":

 print (f"{nome_cliente}seu emprestimo ficou de {soma} 😗\n")
else:
  print ("erro vc nao digitou os campos")
# Out:
# qual o seu nome? :
# EMERSON
# valor do empretimo:
# 200
# gostaria de parcelar? :
# SIM
# informe quantas parcelas:
# 2
# O total de suasparcelas ficaram de 120.0

# %%
ano_atual = input("em que ano estamos?:")
ano_nacimento = input("em que ano vc naceu ?:")

ano_atual = int(ano_atual)
ano_nacimento = int (ano_nacimento)

idade = (ano_atual-ano_nacimento)

print(f"sua idade atual e de {idade}")
if idade >= 18:
 print("vc ja é maior de idade")

else:
  print ("vc é menor de idade ")
# Out:
# em que ano estamos?:2025
# em que ano vc naceu ?:2004
# sua idade atual e de 21
# vc ja é maior de idade

# %%
# dizer se o numero e paar ou impa

while True:
  numero = input("digite um numero:")
  try:
    numero = int(numero)

    if numero % 2 == 0:
      print(" esse numero é par")
    else:
      print(" esse numero é impa")
  except ValueError:
    print("Entrada inválida. Por favor, digite um número inteiro.")
# Out:
# digite um numero:2
#  esse numero é par
# digite um numero:5
#  esse numero é impa
# digite um numero:10
#  esse numero é par
# digite um numero:1
#  esse numero é impa
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1655359687.py in <cell line: 0>()
#       2
#       3 while True:
# ----> 4   numero = input("digite um numero:")
#       5   try:
#       6     numero = int(numero)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %%
while True:
    seu_nome = input("digite seu nome:")
    peso_str = input("digite seu peso:")
    altura_str = input("digite a sua altura:")

    try:
        # Replace comma with period for decimal conversion and convert to float
        peso = float(peso_str.replace(',', '.'))
        altura = float(altura_str.replace(',', '.'))

        # IMC calculation: weight / (height in meters)^2
        IMC = peso / (altura ** 2)

        print(f"Olá {seu_nome} seu IMC foi de {IMC:.2f} ")

        if IMC < 18.5:
            print(f'{seu_nome}, seu peso está abaixo do normal.')
        elif IMC >= 18.5 and IMC <= 24.9:
            print(f'{seu_nome}, seu peso está normal.')
        else:
            print(f'{seu_nome}, você está acima do peso.')

    except ValueError:
        print("Entrada inválida. Por favor, digite números para peso e altura.")
    except ZeroDivisionError:
        print("Altura inválida. A altura não pode ser zero.")
# Out:
# digite seu nome:EMERSON
# digite seu peso:68
# digite a sua altura:1.73
# Olá EMERSON seu IMC foi de 22.72
# EMERSON, seu peso está normal.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1534744890.py in <cell line: 0>()
#       1 while True:
# ----> 2     seu_nome = input("digite seu nome:")
#       3     peso_str = input("digite seu peso:")
#       4     altura_str = input("digite a sua altura:")
#       5
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...

# %%
while True:
    nota1_str = input("digite a primeira nota:")
    nota2_str = input('digite a segunda nota:')

    try:
        # Replace comma with period for decimal conversion and convert to float
        nota1 = float(nota1_str.replace(',', '.'))
        nota2 = float(nota2_str.replace(',', '.'))

        soma = nota1 + nota2
        media = soma / 2

        print(f"A média das notas é: {media:.2f}")

        if media >= 7:
            print("aprovado")
        elif media >= 5: # Use >= 5 for recovery, assuming less than 7
            print("voce esta de recuperação!")
        else:
            print("vc esta reprovado")

    except ValueError:
        print("Entrada inválida. Por favor, digite números para as notas.")
    except ZeroDivisionError:
        # This exception is less likely here unless input handling allows it
        print("Erro na divisão. Verifique as notas inseridas.")
# Out:
# digite a primeira nota:20
# digite a segunda nota:20
# A média das notas é: 20.00
# aprovado
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3700132352.py in <cell line: 0>()
#       1 while True:
# ----> 2     nota1_str = input("digite a primeira nota:")
#       3     nota2_str = input('digite a segunda nota:')
#       4
#       5     try:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
# Definindo um novo conjunto de variáveis de exemplo
cidade_favorita = "Rio de Janeiro"
numero_magico = 777
lista_compras = ["pão", "leite", "ovos", "frutas"]
informacoes_contato = {"email": "exemplo@dominio.com", "telefone": "11987654321"}

print("Novas variáveis disponíveis:")
print("1) cidade_favorita")
print("2) numero_magico")
print("3) lista_compras")
print("4) informacoes_contato")

escolha = input("Digite o número da variável que você quer imprimir (1, 2, 3 ou 4): ")

if escolha == '1':
    print(f"Você escolheu a variável cidade_favorita: {cidade_favorita}")
elif escolha == '2':
    print(f"Você escolheu a variável numero_magico: {numero_magico}")
elif escolha == '3':
    print(f"Você escolheu a variável lista_compras: {lista_compras}")
elif escolha == '4':
    print(f"Você escolheu a variável informacoes_contato: {informacoes_contato}")
else:
    print("Escolha inválida. Por favor, digite 1, 2, 3 ou 4.")
# Out:
# Novas variáveis disponíveis:
# 1) cidade_favorita
# 2) numero_magico
# 3) lista_compras
# 4) informacoes_contato
# Digite o número da variável que você quer imprimir (1, 2, 3 ou 4): 2
# Você escolheu a variável numero_magico: 777

# %%
print(':------------------------:')
print(":   CRIANCA_ESPERANCA    :")
print(':------------------------:')
print(':------------------------:')
print(":MUINTO_OBRIGADO_POR_DOAR:")
print(':------------------------:\n')
valor1 = '10_R$'
valor2 = '20_R$'
valor3 = '50_R$'
valor4 = '100_R$'
valor5 = '0_R$'

print('escolha uma opção para doar\n')

print('(1) para doar 10_R$')
print('(2) para doar 20_R$')
print('(3) para doar 50_R$')
print('(4) para doar 100_R$')
print('(5) cancelar  0_R$')
print('(6) outros valores\n')
opcao_escolhida = input('digite a opcao: ')

if opcao_escolhida == '1':
   print(f"sua doacao foi de {valor1} agradecemos por sua doação")
elif opcao_escolhida == '2':
   print(f"sua doacao foi de {valor2} agradecemos por sua doação")
elif opcao_escolhida == '3':
   print(f"sua doacao foi de {valor3} agradecemos por sua doação")
elif opcao_escolhida == '4':
   print(f"sua doacao foi de {valor4} agradecemos por sua doação")
elif opcao_escolhida == '5':
   print(f"sua doacao foi de {valor5} agradecemos ")
elif opcao_escolhida == '6':
   novo_valor =  input ('digite um valor:')
   print(f"\nSua doação de {novo_valor} R$ foi registrada. Agradecemos por sua doação.")
   print("    .--.")
   print("   | o_o|")
   print("   |:_/ |")
   print("  //   \\ \\")
   print(" |     | |")
   print(" \\     / /")
   print("  `---' ")
   print("   (^_^)")
   print("  ( > < )")
   print("   (  .  )")
   print("    -----")
   print("   ( Y Y )")
   print("   /  `  \\")
   print("  (  ---  )")
   print("   `-----'")
else:
  print("erro na digitacao")
# Out:
# :------------------------:
# :   CRIANCA_ESPERANCA    :
# :------------------------:
# :------------------------:
# :MUINTO_OBRIGADO_POR_DOAR:
# :------------------------:
#
# escolha uma opção para doar
#
# (1) para doar 10_R$
# (2) para doar 20_R$
# (3) para doar 50_R$
# (4) para doar 100_R$
# (5) cancelar  0_R$
# (6) outros valores
#
# digite a opcao: 6
# digite um valor:200
#
# Sua doação de 200 R$ foi registrada. Agradecemos por sua doação.
#     .--.
#    | o_o|
#    |:_/ |
#   //   \ \
#  |     | |
#  \     / /
#   `---'
#    (^_^)
#   ( > < )
#    (  .  )
#     -----
#    ( Y Y )
#    /  `  \
#   (  ---  )
#    `-----'
